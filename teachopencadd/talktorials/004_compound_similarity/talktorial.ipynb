# %% [markdown]
# # Ligand-based screening: compound similarity
#
# Authors:
#
# - Andrea Morger, 2017-2020, [Volkamer lab](https://volkamerlab.org/), Charité
# - Franziska Fritz, CADD seminar, 2018, Charité/FU Berlin
# - Yonghui Chen, 2019-2020, [Volkamer lab](https://volkamerlab.org/), Charité
# - Dominique Sydow, 2018-2020, [Volkamer lab](https://volkamerlab.org/), Charité

# %% [markdown]
# __Talktorial T004__: This talktorial is part of the TeachOpenCADD pipeline described in the [first TeachOpenCADD paper](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-019-0351-x), comprising of **talktorials T001-T010**.

# %% [markdown]
# ## Aim of this talktorial
#
# In this talktorial, we get familiar with different approaches to encode (descriptors, fingerprints) and compare (similarity measures) molecules. Furthermore, we perform a virtual screening in the form of a similarity search for the EGFR inhibitor Gefitinib against our dataset of EGFR-tested compounds from the ChEMBL database filtered by Lipinski's rule of five (see **talktorial 002**).

# %% [markdown]
# ### Contents in _Theory_
#
# * Molecular similarity
# * Molecular descriptors
# * Molecular fingerprints
#   * Substructure-based fingerprints
#   * MACCS fingerprints
#   * Morgan fingerprints and circular fingerprints
# * Molecular similarity measures
#   * Tanimoto coefficient
#   * Dice coefficient
# * Virtual screening
#   * Virtual screening using similarity search
#   * Enrichment plots

# %% [markdown]
# ### Contents in _Practical_
#
# * Import and draw molecules
# * Calculate molecular descriptors
#   * 1D molecular descriptors: Molecular weight
#   * 2D molecular descriptors: MACCS fingerprint
#   * 2D molecular descriptors: Morgan fingerprint
# * Calculate molecular similarity
#   * MACCS fingerprints: Tanimoto and Dice similarity
#   * Morgan fingerprints: Tanimoto and Dice similarity
# * Virtual screening using similarity search
#   * Compare query compound to all compounds in the data set
#   * Distribution of similarity values
#   * Visualize most similar molecules
#   * Generate enrichment plots

# %% [markdown]
# ### References
#
# * Review on "Molecular similarity in medicinal chemistry" ([<i>J. Med. Chem.</i> (2014), <b>57</b>, 3186-3204](http://pubs.acs.org/doi/abs/10.1021/jm401411z))
# * Morgan fingerprints with rdkit ([rdkit tutorial on Morgan fingerprints](http://www.rdkit.org/docs/GettingStartedInPython.html#morgan-fingerprints-circular-fingerprints))
# * ECFP - extended-connectivity fingerprints ([<i>J. Chem. Inf. Model.</i> (2010), <b>50</b>,742-754](https://pubs.acs.org/doi/abs/10.1021/ci100050t))
# * Chemical space
# ([<i>ACS Chem. Neurosci.</i> (2012), <b>19</b>, 649-57](https://www.ncbi.nlm.nih.gov/pubmed/23019491))
# * List of molecular descriptors in rdkit ([rdkit documentation: Descriptors](https://www.rdkit.org/docs/GettingStartedInPython.html#list-of-available-descriptors))
# * List of fingerprints in rdkit ([rdkit documentation: Fingerprints](https://www.rdkit.org/docs/GettingStartedInPython.html#list-of-available-fingerprints))
# * Enrichment plots ([Applied Chemoinformatics, Wiley-VCH Verlag GmbH & Co. KGaA, Weinheim, (2018), **1**, 313-31](https://onlinelibrary.wiley.com/doi/10.1002/9783527806539.ch6h))

# %% [markdown]
# ## Theory

# %% [markdown]
# ### Molecular similarity
#
# Molecular similarity is a well known and often used concept in chemical informatics. Comparing compounds and their properties can be used in many different ways and help us to identify new compounds with desired properties and biological activity.
#
# The similar property principle (SPP) as well as the structure-activity relationship (SAR) approaches are based on the assumption that structurally similar molecules have similar properties and, thus, similar biological activity. In this context, virtual screening follows this idea to search for similar molecules in given a set of molecules with known binding affinity and to propose those as potentially new active molecules.

# %% [markdown]
# ### Molecular descriptors
#
# Similarity can be assessed in many different ways depending on the application (see [<i>J. Med. Chem.</i> (2014), <b>57</b>, 3186-3204</a>](http://pubs.acs.org/doi/abs/10.1021/jm401411z)):
#
# - 1D molecular descriptor: Solubility, logP, molecular weight, melting point.
#   - Global descriptor: only one value represents the whole compound
#   - Usually do not contain enough information to be applied to machine learning (ML)
#   - Can be added to 2D fingerprints to improve molecular encoding for ML
# - 2D molecular descriptors: Molecular graphs, paths, fragments, atom environments
#   - Detailed representation of individual parts of the molecule
#   - Contains many features/bits per molecule called fingerprints
#   - Very often used in similarity search and ML
# - 3D molecular descriptors: Shape, stereochemistry
#   - Less robust than 2D representations because of compound flexibility (what is the "right" conformation of a compound?)
#     Biological similarity
#   - Biological fingerprint, e.g. individual bits represent bioactivity measure against different targets
#   - Independent of molecular structure
#   - Requires experimental (or predicted) data
#
# We already learned how to calculate 1D physicochemical parameters, such as the molecular weight and logP in **talktorial 002**. More information about these descriptors in the rdkit can be found in the [rdkit documentation: Descriptors](https://www.rdkit.org/docs/GettingStartedInPython.html#list-of-available-descriptors).
#
# In the following, we focus on the definition of 2D molecular descriptors. Due to their, mostly, uniqueness per molecule, these descriptors are also called fingerprints.

# %% [markdown]
# ### Molecular fingerprints

# %% [markdown]
# #### Substructure-based fingerprints
#
# Molecular fingerprints are a computational representation of molecules that encode chemical and molecular features in the form of bitstrings, bitvectors or arrays. Each bit corresponds to a predefined molecular feature or environment, where "1" represents the presence and "0" the absence of a feature. Note that some implementations are count-based. Thus, they count how often a specific feature is present.
#
# There are multiple ways to design fingerprints.
# Here, we introduce MACCS keys and Morgan fingerprint as two commonly used 2D fingerprints.
# As can be seen in the [rdkit documentation: Fingerprints](https://www.rdkit.org/docs/GettingStartedInPython.html#list-of-available-fingerprints), rdkit also offers multiple alternate fingerprints.

# %% [markdown]
# #### MACCS fingerprints
#
# Molecular ACCess System
# (MACCS) fingerprints, also termed MACCS structural keys, consist of 166 predefined structural fragments. Each position queries the presence or absence of one particular structural fragment or key.
# The individual keys were empirically defined by medicinal chemists and are simple to use and interpret ([rdkit documentation: MACCS keys](http://rdkit.org/Python_Docs/rdkit.Chem.MACCSkeys-module.html)).
#
# ![Figure 1](images/maccs_fp.png)
#
# *Figure 1*: Illustration of MACCS fingerprint (figure by Andrea Morger).

# %% [markdown]
# #### Morgan fingerprints and circular fingerprints
#
# This family of fingerprints is based on the Morgan algorithm.
# The bits correspond to the circular environments of each atom in a molecule.
# The number of neighboring bonds and atoms to consider is set by the radius.
# Also the length of the bit string can be defined, a longer bit string will be modded to the desired length.
# Therefore, the Morgan fingerprint is not limited to a certain number of bits.
# More about the Morgan fingerprint can be found in the
# [rdkit documentation](http://www.rdkit.org/docs/GettingStartedInPython.html#morgan-fingerprints-circular-fingerprints).
# Extended connectivity fingerprints (ECFP) are also commonly used fingerprints that are derived using a variant of the Morgan algorithm, see [<i>J. Chem. Inf. Model.</i> (2010), <b>50</b>,742-754](https://pubs.acs.org/doi/abs/10.1021/ci100050t) for further information.
#
# ![Figure 2](images/morgan_fp.png)
#
# *Figure 2*: Illustration of the Morgan circular fingerprint (figure by Andrea Morger).

# %% [markdown]
# ### Molecular similarity measures
#
# Once the descriptors/fingerprints are calculated, they can be compared to assess the similarity between two molecules. Molecular similarity can be quantified with a number of different similarity coefficients, two common similarity measures are the Tanimoto and Dice index ([<i>J. Med. Chem.</i> (2014), <b>57</b>, 3186-3204](http://pubs.acs.org/doi/abs/10.1021/jm401411z)).

# %% [markdown]
# #### Tanimoto coefficient
#
# $$T _{c}(A,B) = \frac{c}{a+b-c}$$
#
# - a: number of features present in compound A
# - b: number of features present in compound B
# - c: number of features shared by compounds A and B

# %% [markdown]
# #### Dice coefficient
#
# $$D_{c}(A,B) = \frac{c}{\frac{1}{2}(a+b)}$$
#
# - a: number of features present in compound A
# - b: number of features present in compound B
# - c: number of features shared by compounds A and B
#
# The similarity measures usually consider the number of positive bits (1's) present in either fingerprint and the number of positive bits that both have in common.
# Dice similarity usually returns higher values than Tanimoto similarity because of their denominators:
#
# $$\frac{c}{a+b-c} \leq \frac{c}{\frac{1}{2}(a+b)}$$

# %% [markdown]
# ### Virtual screening
#
# The challenge in early stages of drug discovery is to narrow down a set of small molecules (compounds) from the large existing chemical space that are potentially binding to the target under investigation. Note that this chemical space is vast: Small molecules can be made of 10<sup>20</sup> combinations of chemical moieties ([<i>ACS Chem. Neurosci.</i> (2012), <b>19</b>, 649-57](https://www.ncbi.nlm.nih.gov/pubmed/23019491)).
#
# Since experimental high-throughput screening (HTS) for the activity of all those small molecules against the target of interest is cost and time intensive, computer-aided methods are invoked to propose a focused list of small molecules to be tested. This process is called virtual (high-throughput) screening: a large library of small molecules is filtered by rules and/or patterns, in order to identify those small molecules that are most likely to bind a target under investigation.

# %% [markdown]
# #### Virtual screening using similarity search
#
# Comparing a set of novel molecules against a (or several) known active molecule(s) to find the most similar ones can be used as a simple way of virtual screening.
# Given the similar property principle, we can assume that the most similar molecules, e.g. to a known inhibitor, also have similar effects. Requirements for a similarity search are the following (as discussed in detail above):
#
# * A representation that encodes chemical/molecular features
# * A potential weighting of features (optional)
# * A similarity measurement
#
# A similarity search can be performed by calculating the similarity between one compound and all compounds in a specific database. Ranking the compounds of the database by their similarity coefficient yields the most similar molecules at the top.

# %% [markdown]
# #### Enrichment plots
#
# Enrichment plots are used to validate virtual screening results, which display the ratio of active compounds detected in the top x% of the ranked list, i.e.:
#
# * the ratio of top-ranked molecules (x-axis) from the whole dataset vs.
# * the ratio of active molecules (y-axis) from the whole dataset.
#
# ![Figure 3](images/enrichment_plot.png)
#
# *Figure 3*: Example of enrichment plot for virtual screening results.

# %% [markdown]
# ## Practical
#
# In the first part of this practical section, we will use rdkit to encode molecules (molecular fingerprints) and compare them in order to calculate their similarity (molecular similarity measures), as discussed in the theory section above.
#
# In the second part, we will use these encoding and comparison techniques to conduct a similarity search (virtual screening):
# We use the known EGFR inhibitor Gefitinib as query and search for similar compounds in our data set of compounds tested on EGFR, which we collected from the ChEMBL database in **talktorial 001** and filtered by Lipinski's rule of five in **talktorial 002**.

# %% [markdown]
# ### Import and draw molecules
#
# First, we define and draw eight example molecules, which we will encode and compare later on.
# The molecules in SMILES format are converted to rdkit molecule objects and visualized with the rdkit `Draw` function.

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
from rdkit import Chem, DataStructs
from rdkit.Chem import PandasTools, Draw, Descriptors, MACCSkeys, rdFingerprintGenerator

# %%
HERE = Path(_dh[-1])
DATA = HERE / "data"

# %% [markdown]
# There are some molecule examples.

# %%
# Molecules in SMILES format
molecule_smiles = [
    "CC1C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4O)O)O)O)C(=O)N)N(C)C)O",
    "CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C(=O)O)C",
    "C1=COC(=C1)CNC2=CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl",
    "CCCCCCCCCCCC(=O)OCCOC(=O)CCCCCCCCCCC",
    "C1NC2=CC(=C(C=C2S(=O)(=O)N1)S(=O)(=O)N)Cl",
    "CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C",
    "CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4O)O)O)O)C(=O)N)N(C)C)O",
    "CC1C(CC(=O)C2=C1C=CC=C2O)C(=O)O"
]

# Construct list of molecule names
molecule_names = [
    "Doxycycline",
    "Amoxicilline",
    "Furosemide",
    "Glycol dilaurate",
    "Hydrochlorothiazide",
    "Isotretinoin",
    "Tetracycline",
    "Hemi-cycline D"
]

# Construct list of ROMol objects
molecules = [Chem.MolFromSmiles(molecule) for molecule in molecule_smiles]

# Draw molecules
Draw.MolsToGridImage(molecules, molsPerRow=2, subImgSize=(450, 150), legends=molecule_names)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=900x600 at 0x7F59941B00A0>

# %% [markdown]
# ### Calculate molecular descriptors
#
# We extract and generate 1D and 2D molecular descriptors to compare our molecules.
# For 2D descriptors, different types of fingerprints are generated to be used later for the calculation of the molecular similarity.

# %% [markdown]
# #### 1D molecular descriptors: Molecular weight
#
# We calculate the molecular weight of our example structures.

# %%
molecule_weights = [Descriptors.MolWt(molecule) for molecule in molecules]

# %% [markdown]
# We draw our molecular structures with their similar molecular weight for visual comparison: is the molecular weight a feasible descriptor for compound similarity?

# %%
# Generate DataFrame for the results
molecules_df = pd.DataFrame(
    {
        "smiles": molecule_smiles,
        "name": molecule_names,
        "molecule_weight": molecule_weights,
    }
)

# Add molecule column
PandasTools.AddMoleculeColumnToFrame(molecules_df, smilesCol='smiles') 

# Sort by molecular weight
molecules_sorted_df = molecules_df.sort_values(["molecule_weight"], ascending=False)
molecules_sorted_df[["smiles", "name", "molecule_weight"]]
# Out:
#                                               smiles                 name  \
# 0  CC1C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...          Doxycycline
# 6  CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...         Tetracycline
# 3               CCCCCCCCCCCC(=O)OCCOC(=O)CCCCCCCCCCC     Glycol dilaurate
# 1  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...         Amoxicilline
# 2     C1=COC(=C1)CNC2=CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl           Furosemide
# 5         CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C         Isotretinoin
# 4          C1NC2=CC(=C(C=C2S(=O)(=O)N1)S(=O)(=O)N)Cl  Hydrochlorothiazide
# 7                    CC1C(CC(=O)C2=C1C=CC=C2O)C(=O)O       Hemi-cycline D
#
#    molecule_weight
# 0          444.440
# 6          444.440
# 3          426.682
# 1          365.411
# 2          330.749
# 5          300.442
# 4          297.745
# 7          220.224

# %% [markdown]
# Draw the molecules with their molecular weight.

# %%
Draw.MolsToGridImage(
    molecules_sorted_df["ROMol"],
    legends=[
        f"{molecule_name}: {str(round(molecule_weight, 2))} Da"
        for molecule_name, molecule_weight in zip(
            molecules_sorted_df["name"],
            molecules_sorted_df["molecule_weight"],
        )
    ],
    subImgSize=(450, 150), molsPerRow=2
)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=900x600 at 0x7F59941B6460>

# %% [markdown]
# As we can see, molecules with similar molecular weight can have a similar structure (e.g. Doxycycline/Tetracycline), however they can also have a similar number of atoms in completely different arrangements (e.g. Doxycycline/Glycol dilaurate or Hydrochlorothiazide/Isotretinoin).
#
# In order to account for more detailed properties of a molecule, we now take a look at 2D molecular descriptors.

# %% [markdown]
# #### 2D molecular descriptors: MACCS fingerprint
#
# MACCS fingerprints can be easily generated using rdkit. As explicit bitvectors are not human-readable, we will further transform them to bitstrings.

# %%
# For Doxycycline
maccs_fp1 = MACCSkeys.GenMACCSKeys(molecules_df["ROMol"][0]) 
# For Amoxicilline
maccs_fp2 = MACCSkeys.GenMACCSKeys(molecules_df["ROMol"][1])  
maccs_fp1

# %% [markdown]
# Show the fingerprint as bitstring.

# %%
maccs_fp1.ToBitString()
# Out:
# '00000000000000000000000000100000000000000000000000100110000000000010000010101000000011100100110101010100010000101100010000100001000101001001111111101111101011111111110'

# %% [markdown]
# Generate MACCS fingerprints for all molecules.

# %%
maccs_fp_list = [MACCSkeys.GenMACCSKeys(molecule) for molecule in molecules_df['ROMol']]

# %% [markdown]
# #### 2D molecular descriptors: Morgan fingerprint
#
# We also calculate the circular Morgan fingerprints with rdkit.
# With two different functions, the Morgan fingerprint can be calculated either as int or bit vector.

# %% [markdown]
# - Generate Morgan fingerprint (as int vector), by default the radius is 2 and the vector is 2048 long.

# %%
molecule1 = molecules_df["ROMol"][0]
circular_fp1 = rdFingerprintGenerator.GetCountFPs([molecule1])[0]
circular_fp1

# %%
print(f"Print non-zero elements:\n{circular_fp1.GetNonzeroElements()}")
# Out:
# Print non-zero elements:
# {45: 1, 118: 1, 140: 1, 163: 1, 276: 1, 303: 1, 309: 1, 314: 2, 371: 1, 438: 1, 525: 1, 557: 1, 650: 3, 673: 1, 699: 1, 807: 6, 824: 1, 829: 1, 881: 1, 1009: 1, 1019: 5, 1027: 1, 1039: 1, 1057: 3, 1060: 1, 1061: 1, 1070: 1, 1082: 1, 1088: 1, 1119: 1, 1154: 1, 1163: 2, 1171: 1, 1257: 1, 1296: 1, 1309: 1, 1341: 1, 1380: 9, 1389: 1, 1457: 1, 1471: 1, 1487: 1, 1582: 1, 1602: 3, 1607: 1, 1630: 1, 1747: 1, 1750: 2, 1831: 1, 1833: 1, 1857: 1, 1873: 3, 1917: 1, 1932: 1, 2000: 1, 2029: 1}

# %% [markdown]
# - Generate Morgan fingerprint (as bit vector), by default the radius is 2 and the fingerprint is 2048 long.

# %%
circular_bit_fp1 = rdFingerprintGenerator.GetFPs([molecule1])[0]
circular_bit_fp1

# %%
print(f"Print top 400 fingerprint bits:\n{circular_bit_fp1.ToBitString()[:400]}")
# Out:
# Print top 400 fingerprint bits:
# ...

# %% [markdown]
# Generate the Morgan fingerprint (as bit vector) for all molecules.

# %%
circular_fp_list = rdFingerprintGenerator.GetFPs(molecules_df['ROMol'].tolist())

# %% [markdown]
# ### Calculate molecular similarity
#
# In the following, we will apply two similarity measures, i.e. **Tanimoto** and **Dice**, to our two fingerprint types, i.e. **MACCS** and **Morgan** fingerprints.
#
# Example: Two MACCS fingerprints compared with the Tanimoto similarity.

# %% [markdown]
# - Calculate Tanimoto coefficients between two molecules.

# %%
print(
    f"Tanimoto coefficients between Doxycycline and Amoxicilline using maccs fingerprints: \
    {DataStructs.TanimotoSimilarity(maccs_fp1, maccs_fp2)}"
)
# Out:
# Tanimoto coefficients between Doxycycline and Amoxicilline using maccs fingerprints:     0.5909090909090909

# %% [markdown]
# - Calculate Tanimoto coefficient between the same molecule.

# %%
print(
    f"Tanimoto coefficients between the same molecule: \
    {DataStructs.TanimotoSimilarity(maccs_fp1, maccs_fp1)}"
)
# Out:
# Tanimoto coefficients between the same molecule:     1.0

# %% [markdown]
# In the following, we want to compare a query compound with our molecule list.
# Therefore, we use the rdkit functions ```BulkTanimotoSimilarity``` and ```BulkDiceSimilarity``` that calculate the similarity of a query fingerprint with a list of fingerprints, based on a similarity measure, i.e. either the Tanimoto or Dice similarity.

# %% [markdown]
# After calculating the similarity, we want to draw our ranked molecules with the following function:

# %%
def draw_ranked_molecules(similarity_df_sorted, sorted_column):
    """
    Draw molecules from a (sorted) DataFrame.
    Need the sorted DataFrame and the column which the DataFrame sorted by.
    
    Parameters
    ----------
    similarity_df_sorted : pd.DataFrame
        The pd.DataFrame which has been sorted by similarity value.
    sorted_column : str
        The name of the column, which the pd.DataFrame sorted by.
        
    Returns
    -------
    Draw.MolsToGridImage : Draw.MolsToGridImage
        The picture with 2D sturctures of the molecules.
    """
    # Define labels: first molecule is query, following molecules start from rank 1
    ranks = [f"#{str(i)}: " for i in range(len(similarity_df_sorted))]
    ranks[0] = "Query: "

    # Draw most similar molecules to Doxycycline (Tanimoto and MACCS fingerprint)
    top_smiles = similarity_df_sorted["smiles"].tolist()
    top_molecules = [Chem.MolFromSmiles(smiles) for smiles in top_smiles]
    top_names = [
        f"{rank}{molecule_name}, similarity: ({str(round(similarity, 2))})"
        for rank, molecule_name, similarity in zip(
            ranks,
            similarity_df_sorted["name"].tolist(),
            similarity_df_sorted[sorted_column],
        )
    ]

    return Draw.MolsToGridImage(
        top_molecules, legends=top_names, molsPerRow=2, subImgSize=(450, 150)
    )

# %% [markdown]
# In the following, we will investigate all combinations of MACCS/Morgan fingerprint comparisons based on the Tanimoto/Dice similarity measure. Therefore, we create a DataFrame that will summarize our results:

# %%
# Generate DataFrame for the results
similarity_df = pd.DataFrame({"smiles": molecule_smiles, "name": molecule_names})

# %% [markdown]
# #### MACCS fingerprints: Tanimoto similarity and Dice similarity

# %%
# Add similarity scores to DataFrame
similarity_df["tanimoto_maccs"] = DataStructs.BulkTanimotoSimilarity(maccs_fp1, maccs_fp_list)

# %% [markdown]
# DataFrame sorted by Tanimoto similarity of MACCS fingerprints.

# %%
similarity_df_sorted_tanimoto_maccs = similarity_df.sort_values(
    ["tanimoto_maccs"], ascending=False
)
similarity_df_sorted_tanimoto_maccs
# Out:
#                                               smiles                 name  \
# 0  CC1C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...          Doxycycline
# 6  CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...         Tetracycline
# 1  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...         Amoxicilline
# 7                    CC1C(CC(=O)C2=C1C=CC=C2O)C(=O)O       Hemi-cycline D
# 2     C1=COC(=C1)CNC2=CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl           Furosemide
# 4          C1NC2=CC(=C(C=C2S(=O)(=O)N1)S(=O)(=O)N)Cl  Hydrochlorothiazide
# 5         CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C         Isotretinoin
# 3               CCCCCCCCCCCC(=O)OCCOC(=O)CCCCCCCCCCC     Glycol dilaurate
#
#    tanimoto_maccs
# 0        1.000000
# 6        0.928571
# 1        0.590909
# 7        0.403509
# 2        0.321839
# 4        0.306818
# 5        0.288136
# 3        0.149254

# %% [markdown]
# Draw molecules ranked by Tanimoto similarity of MACCS fingerprints.

# %%
draw_ranked_molecules(similarity_df_sorted_tanimoto_maccs, "tanimoto_maccs")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=900x600 at 0x7F59574F1520>

# %% [markdown]
# With MACCS fingerprints, Tetracycline is the most similar molecule (high score), followed by Amoxicilline. In contrast to the 1D descriptor molecular weight, the linear molecule Glycol dilaurate is recognized as dissimilar (last rank).

# %%
# Add similarity scores to DataFrame
similarity_df["dice_maccs"] = DataStructs.BulkDiceSimilarity(maccs_fp1, maccs_fp_list)

# %% [markdown]
# DataFrame sorted by Dice similarity of MACCS fingerprints.

# %%
similarity_df_sorted_dice_maccs = similarity_df.sort_values(
    ["dice_maccs"], ascending=False
)
similarity_df_sorted_dice_maccs
# Out:
#                                               smiles                 name  \
# 0  CC1C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...          Doxycycline
# 6  CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...         Tetracycline
# 1  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...         Amoxicilline
# 7                    CC1C(CC(=O)C2=C1C=CC=C2O)C(=O)O       Hemi-cycline D
# 2     C1=COC(=C1)CNC2=CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl           Furosemide
# 4          C1NC2=CC(=C(C=C2S(=O)(=O)N1)S(=O)(=O)N)Cl  Hydrochlorothiazide
# 5         CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C         Isotretinoin
# 3               CCCCCCCCCCCC(=O)OCCOC(=O)CCCCCCCCCCC     Glycol dilaurate
#
#    tanimoto_maccs  dice_maccs
# 0        1.000000    1.000000
# 6        0.928571    0.962963
# 1        0.590909    0.742857
# 7        0.403509    0.575000
# 2        0.321839    0.486957
# 4        0.306818    0.469565
# 5        0.288136    0.447368
# 3        0.149254    0.259740

# %% [markdown]
# Tanimoto and Dice similarity measures by definition result in the same ranking of molecules, with higher values for the Dice similarity (see Tanimoto and Dice equations in the theory section of this talktorial).

# %% [markdown]
# #### Morgan fingerprints: Tanimoto similarity and Dice similarity

# %%
# Add similarity scores to DataFrame
similarity_df["tanimoto_morgan"] = DataStructs.BulkTanimotoSimilarity(
    circular_bit_fp1, circular_fp_list
)
similarity_df["dice_morgan"] = DataStructs.BulkDiceSimilarity(
    circular_bit_fp1, circular_fp_list
)

# %% [markdown]
# DataFrame sorted by Tanimoto similarity of Morgan fingerprint.

# %%
similarity_df_sorted_tanimoto_morgan = similarity_df.sort_values(
    ["tanimoto_morgan"], ascending=False
)
similarity_df_sorted_tanimoto_morgan
# TODO: CI : similarity_df_sorted_tanimoto_morgan["tanimoto_morgan"]
# Out:
#                                               smiles                 name  \
# 0  CC1C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...          Doxycycline
# 6  CC1(C2CC3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C4...         Tetracycline
# 7                    CC1C(CC(=O)C2=C1C=CC=C2O)C(=O)O       Hemi-cycline D
# 1  CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=C(C=C3)O)N)C...         Amoxicilline
# 2     C1=COC(=C1)CNC2=CC(=C(C=C2C(=O)O)S(=O)(=O)N)Cl           Furosemide
# 5         CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC(=O)O)C)C         Isotretinoin
# 4          C1NC2=CC(=C(C=C2S(=O)(=O)N1)S(=O)(=O)N)Cl  Hydrochlorothiazide
# 3               CCCCCCCCCCCC(=O)OCCOC(=O)CCCCCCCCCCC     Glycol dilaurate
#
#    tanimoto_maccs  dice_maccs  tanimoto_morgan  dice_morgan
# 0        1.000000    1.000000         1.000000     1.000000
# 6        0.928571    0.962963         0.534247     0.696429
# 7        0.403509    0.575000         0.308824     0.471910
# 1        0.590909    0.742857         0.144444     0.252427
# 2        0.321839    0.486957         0.098901     0.180000
# 5        0.288136    0.447368         0.067416     0.126316
# 4        0.306818    0.469565         0.058824     0.111111
# 3        0.149254    0.259740         0.054795     0.103896

# %% [markdown]
# Draw molecules ranked by Tanimoto similarity of Morgan fingerprints.

# %%
draw_ranked_molecules(similarity_df_sorted_tanimoto_morgan, "tanimoto_morgan")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=900x600 at 0x7F5957513700>

# %% [markdown]
# Compare the MACCS and Morgan similarities by plotting Tanimoto(Morgan) vs Tanimoto(MACCS)

# %%
fig, axes = plt.subplots(figsize=(6, 6), nrows=1, ncols=1)
similarity_df_sorted_tanimoto_morgan.plot(
    "tanimoto_maccs", "tanimoto_morgan", kind="scatter", ax=axes
)
plt.plot([0, 1], [0, 1], "k--")
axes.set_xlabel("MACCS")
axes.set_ylabel("Morgan")
plt.show()

# %% [markdown]
# Usage of different fingerprints (here: MACCS and Morgan fingerprints) results in different similarity values (here: Tanimoto similarity) and thus potentially also in different rankings of molecule similarity as shown here.
#
# Morgan fingerprints also recognize Tetracycline as the most similar compound to Doxycycline (but with lower score), and Clycol dilaurate as most dissimilar. However, ranked second is Hemi-cycline D, a structural part of cyclines - possibly because of the atom environment-based algorithm of Morgan fingerprints (whereas MACCS fingerprints rather ask for the occurrence of certain properties).

# %% [markdown]
# ### Virtual screening using similarity search
#
# Now that we have learned how to calculate fingerprints and the similarity between them, we can apply this knowledge to a similarity search of a query compound against a full data set of compounds.
#
# We use the known EGFR inhibitor Gefitinib as query and search for similar compounds in our data set of compounds tested on EGFR, which we collected from the ChEMBL database in **talktorial 001** and filtered by Lipinski's rule of five in **talktorial 002**.
#
# #### Compare query compound to all compounds in the data set
#
# We import compounds from a *csv* file containing the filtered EGFR-tested compounds from the ChEMBL database as provided by **talktorial 002**. Given one query compound (here Gefitinib), we screen that data set for similar compounds.

# %% [markdown]
# Import data from csv file containing compounds in SMILES format.

# %%
molecules_df = pd.read_csv(
    HERE / "../002_compound_adme/data/EGFR_compounds_lipinski.csv",
    delimiter=";",
    usecols=["molecule_chembl_id", "smiles", "pIC50"],
)
molecules_df.head(5)
# Out:
#   molecule_chembl_id      pIC50                               smiles
# 0        CHEMBL63786  11.522879    Brc1cccc(Nc2ncnc3cc4ccccc4cc23)c1
# 1        CHEMBL53711  11.221849   CN(C)c1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 2        CHEMBL35820  11.221849  CCOc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OCC
# 3        CHEMBL53753  11.096910      CNc1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 4        CHEMBL66031  11.096910  Brc1cccc(Nc2ncnc3cc4[nH]cnc4cc23)c1

# %% [markdown]
# Generate Mol object from SMILES of query compound (Gefitinib, Iressa).

# %%
query = Chem.MolFromSmiles("COC1=C(OCCCN2CCOCC2)C=C2C(NC3=CC(Cl)=C(F)C=C3)=NC=NC2=C1")
query

# %% [markdown]
# Generate MACCS and Morgan fingerprints for query compound.

# %%
maccs_fp_query = MACCSkeys.GenMACCSKeys(query)
circular_fp_query = rdFingerprintGenerator.GetCountFPs([query])[0]

# %% [markdown]
# Generate MACCS and Morgan fingerprints for all molecules in file.

# %%
PandasTools.AddMoleculeColumnToFrame(molecules_df, "smiles")
circular_fp_list = rdFingerprintGenerator.GetCountFPs(molecules_df["ROMol"].tolist())
maccs_fp_list = [MACCSkeys.GenMACCSKeys(molecule) for molecule in molecules_df["ROMol"].tolist()]

# %% [markdown]
# Calculate Tanimoto similarity for query compound (Gefitinib) and all molecules in file (MACCS, Morgan).

# %%
molecules_df["tanimoto_maccs"] = DataStructs.BulkTanimotoSimilarity(maccs_fp_query, maccs_fp_list)
molecules_df["tanimoto_morgan"] = DataStructs.BulkTanimotoSimilarity(circular_fp_query, circular_fp_list)

# %% [markdown]
# Calculate Dice similarity for query compound (Gefitinib) and all molecules in file (MACCS, Morgan).

# %%
molecules_df["dice_maccs"] = DataStructs.BulkDiceSimilarity(maccs_fp_query, maccs_fp_list)
molecules_df["dice_morgan"] = DataStructs.BulkDiceSimilarity(circular_fp_query, circular_fp_list)
# TODO: CI : dice_circular

# %%
molecules_df.head(3)
# Out:
#   molecule_chembl_id      pIC50                               smiles  \
# 0        CHEMBL63786  11.522879    Brc1cccc(Nc2ncnc3cc4ccccc4cc23)c1
# 1        CHEMBL53711  11.221849   CN(C)c1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 2        CHEMBL35820  11.221849  CCOc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OCC
#
#                                                ROMol  tanimoto_maccs  \
# 0  <img data-content="rdkit/molecule" src="data:i...        0.409836
# 1  <img data-content="rdkit/molecule" src="data:i...        0.484375
# 2  <img data-content="rdkit/molecule" src="data:i...        0.666667
#
#    tanimoto_morgan  dice_maccs  dice_morgan
# 0         0.324786    0.581395     0.490323
# 1         0.327434    0.652632     0.493333
# 2         0.445455    0.800000     0.616352

# %% [markdown]
# #### Distribution of similarity values
#
# As mentioned in the theory section, compared for the same fingerprint (e.g. MACCS fingerprints), Tanimoto similarity values are lower than Dice similarity values.
# Also, comparing two different fingerprints (e.g. MACCS and Morgan fingerprints), the similarity measure values (e.g. Tanimotot similarity) vary.
#
# We can have a look at the distributions by plotting histograms.

# %% [markdown]
# Firstly, we can plot distribution of Tanimoto similarity of MACCS fingerprints.

# %%
fig, axes = plt.subplots(figsize=(10, 6), nrows=2, ncols=2)
molecules_df.hist(["tanimoto_maccs"], ax=axes[0, 0])
molecules_df.hist(["tanimoto_morgan"], ax=axes[0, 1])
molecules_df.hist(["dice_maccs"], ax=axes[1, 0])
molecules_df.hist(["dice_morgan"], ax=axes[1, 1])
axes[1, 0].set_xlabel("similarity value")
axes[1, 0].set_ylabel("# molecules")
plt.show()

# %% [markdown]
# Secondly, We can compare similarities here. This time let's directly compare Tanimoto and Dice similarities for the two fingerprints

# %%
fig, axes = plt.subplots(figsize=(12, 6), nrows=1, ncols=2)

molecules_df.plot("tanimoto_maccs", "dice_maccs", kind="scatter", ax=axes[0])
axes[0].plot([0, 1], [0, 1], "k--")
axes[0].set_xlabel("Tanimoto (MACCS)")
axes[0].set_ylabel("Dice (MACCS)")

molecules_df.plot("tanimoto_morgan", "dice_morgan", kind="scatter", ax=axes[1])
axes[1].plot([0, 1], [0, 1], "k--")
axes[1].set_xlabel("Tanimoto (Morgan)")
axes[1].set_ylabel("Dice (Morgan)")

plt.show()

# %% [markdown]
# Similarity distributions are important to interpret similarity values, e.g. a value of 0.6 needs to be evaluated differently for MACCS or Morgan fingerprints, as well as Tanimoto or Dice similarities.
#
# In the following, we draw the most similar molecules for the Tanimoto similarity based on Morgan fingerprints.

# %% [markdown]
# #### Visualize most similar molecules

# %% [markdown]
# We visually inspect the structure of Gefitinib in comparison to the most similar molecules in our ranking, including the information about their bioactivity (pIC50 derived from ChEMBL in **talktorial 001**).

# %% [markdown]
# Here, we sort the DataFrame by tanimoto_morgan.

# %%
molecules_df.sort_values(["tanimoto_morgan"], ascending=False, inplace=True)
molecules_df.head(3)
# Out:
#      molecule_chembl_id     pIC50  \
# 2188          CHEMBL939  6.288193
# 730         CHEMBL14699  8.000000
# 1421       CHEMBL299672  7.148742
#
#                                               smiles  \
# 2188  COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN4CCOCC4
# 730    COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCN4CCOCC4
# 1421   COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN4CCCC4
#
#                                                   ROMol  tanimoto_maccs  \
# 2188  <img data-content="rdkit/molecule" src="data:i...        1.000000
# 730   <img data-content="rdkit/molecule" src="data:i...        1.000000
# 1421  <img data-content="rdkit/molecule" src="data:i...        0.919355
#
#       tanimoto_morgan  dice_maccs  dice_morgan
# 2188         1.000000    1.000000     1.000000
# 730          0.923913    1.000000     0.960452
# 1421         0.843750    0.957983     0.915254

# %% [markdown]
# Show the query and top molecules with bioactivity data.

# %%
top_molecules = molecules_df[:11].reset_index()
legends = [
    f"#{index+1} {molecule['molecule_chembl_id']}, pIC50={str(round(molecule['pIC50'], 2))}" 
    for index, molecule in top_molecules.iterrows()
]

Chem.Draw.MolsToGridImage(
    mols=[query] + top_molecules["ROMol"][:11].tolist(),
    legends=(["Gefitinib"] + legends),
    molsPerRow=4,
)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x600 at 0x7F59573BFA00>

# %% [markdown]
# The top ranked molecules for Gefitinib are first Gefitinib entries (rank 1 and 2) in our dataset, followed by alterations of Gefitinib, e.g. different benzole substitution patterns.
# Note: ChEMBL contains the complete structure-activity relationship analysis for Gefitinib (being a well-studied compound), therefore it is not surprising to have that many Gefitinib-like compounds in our dataset.
#
# We now check how well the similarity search is able to distinguish between active and inactive compounds based on our dataset. Therefore, we use the bioactivity values, which we collected from ChEMBL for each compound (bioactivity against EGFR) in **talktorial 001**.

# %% [markdown]
# #### Generate enrichment plots
#
# In order to validate our virtual screening and see the ratio of active compounds detected, we generate an enrichment plot.
#
# Enrichment plots show
#
# * the ratio of top-ranked molecules (x-axis) from the whole dataset vs.
# * the ratio of active molecules (y-axis) from the whole dataset.
#
# We compare the Tanimoto similarity for MACCS and Morgan fingerprints.
#
# In order to decide whether we treat a molecule as active or inactive, we apply the commonly used pIC50 cut-off value of 6.3. Although there are several suggestions ranging from an pIC50 cut-off values of 5 to 7 in the literature or even to define an exclusion range when not to take data points, we think this cutoff is reasonable.
# The same cut-off will be used for machine learning in **talktorial 010**.

# %%
molecules_df.head(3)
# Out:
#      molecule_chembl_id     pIC50  \
# 2188          CHEMBL939  6.288193
# 730         CHEMBL14699  8.000000
# 1421       CHEMBL299672  7.148742
#
#                                               smiles  \
# 2188  COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN4CCOCC4
# 730    COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCN4CCOCC4
# 1421   COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1OCCCN4CCCC4
#
#                                                   ROMol  tanimoto_maccs  \
# 2188  <img data-content="rdkit/molecule" src="data:i...        1.000000
# 730   <img data-content="rdkit/molecule" src="data:i...        1.000000
# 1421  <img data-content="rdkit/molecule" src="data:i...        0.919355
#
#       tanimoto_morgan  dice_maccs  dice_morgan
# 2188         1.000000    1.000000     1.000000
# 730          0.923913    1.000000     0.960452
# 1421         0.843750    0.957983     0.915254

# %%
def get_enrichment_data(molecules_df, similarity_measure, threshold):
    """
    Calculates x and y values for enrichment plot:
        x - % ranked dataset
        y - % true actives identified
        
    Parameters
    ----------
    molecules_df : pd.DataFrame
        The pd.DataFrame with similarity value.
    similarity_measure : str
        Column name which will be used to sort the DataFrame． 
    threshold : float
        pIC50 cut-off value used to discriminate active and inactive compounds
        
    Returns
    -------
    enrichment_df : pd.DataFrame
        Enrichment plot data, i.e. percentage of ranked dataset by similarity vs. percentage of identified true actives.
    """

    # Get number of molecules in data set
    molecules_all = len(molecules_df)

    # Get number of active compounds in data set
    actives_all = sum(molecules_df["pIC50"] >= threshold)

    # Initialize a list that will hold the counter for actives and compounds while iterating through our dataset
    actives_counter_list = []

    # Initialize counter for actives
    actives_counter = 0

    # Note: Data must be ranked for enrichment plots:
    # Sort compounds by selected similarity measure
    molecules_df.sort_values([similarity_measure], ascending=False, inplace=True)

    # Iterate over the ranked dataset and check each compound if active (by checking bioactivity)
    for value in molecules_df["pIC50"]:
        if value >= threshold:
            actives_counter += 1
        actives_counter_list.append(actives_counter)

    # Transform number of molecules into % ranked dataset
    molecules_percentage_list = [i / molecules_all for i in range(1, molecules_all + 1)]

    # Transform number of actives into % true actives identified
    actives_percentage_list = [i / actives_all for i in actives_counter_list]

    # Generate DataFrame with x and y values as well as label
    enrichment_df = pd.DataFrame(
        {
            "% ranked dataset": molecules_percentage_list,
            "% true actives identified": actives_percentage_list,
            "similarity_measure": similarity_measure,
        }
    )

    return enrichment_df

# %% [markdown]
# Set the threshold and get the enrichment data.

# %%
# pIC50 cut-off value used to discriminate active and inactive compounds
threshold = 6.3

# Define similarity measures to be plotted
similarity_measures = ["tanimoto_maccs", "tanimoto_morgan"]

# Generate a list of DataFrames containing all enrichment plot data for all similarity measures
enrichment_data = [
    get_enrichment_data(molecules_df, similarity_measure, threshold)
    for similarity_measure in similarity_measures
]

# %% [markdown]
# Prepare data set for plotting.

# %%
# TODO: CI : enrichment_df

# Concatenate per-similarity measure DataFrames to one DataFrame
# - different similarity measures are still distinguishable by the "similarity_measure" column
enrichment_df = pd.concat(enrichment_data)

# %%
fig, ax = plt.subplots(figsize=(6, 6))

fontsize = 20

for key, group in enrichment_df.groupby(["similarity_measure"]):
    ax = group.plot(
        ax=ax,
        x="% ranked dataset",
        y="% true actives identified",
        label=key,
        alpha=0.5,
        linewidth=4,
    )
ax.set_ylabel("% True actives identified", size=fontsize)
ax.set_xlabel("% Ranked dataset", size=fontsize)

# Ratio of actives in dataset
ratio = sum(molecules_df["pIC50"] >= threshold) / len(molecules_df)

# Plot optimal curve
ax.plot([0, ratio, 1], [0, 1, 1], label="Optimal curve", color="black", linestyle="--")

# Plot random curve
ax.plot([0, 1], [0, 1], label="Random curve", color="grey", linestyle="--")

plt.tick_params(labelsize=16)
plt.legend(
    labels=["MACCS", "Morgan", "Optimal", "Random"],
    loc=(0.5, 0.08),
    fontsize=fontsize,
    labelspacing=0.3,
)

# Save plot - use bbox_inches to include text boxes:
# https://stackoverflow.com/questions/44642082/text-or-legend-cut-from-matplotlib-figure-on-savefig?rq=1
plt.savefig(DATA / "enrichment_plot.png", dpi=300, bbox_inches="tight", transparent=True)

plt.show()

# %% [markdown]
# Enrichment plots show a slightly better performance for fingerprint comparison based on Morgan fingerprints than based on MACCS fingerprints.

# %%
def print_data_ef(percentage_ranked_dataset, enrichment_df):
    '''
    Get EF for x% of ranked dataset
        
    Parameters
    ----------
    percentage_ranked_dataset : float / int
        default the x% (percentage_ranked_dataset%) of ranked dataset.
    enrichment_df : pd.DataFrame
        The pd.DataFrame with ranked dataset and true actives identified.
        
    Returns
    -------
    None
    '''
    data_ef = enrichment_df[
        enrichment_df["% ranked dataset"] <= percentage_ranked_dataset / 100
    ].tail(1)
    data_ef = round(100 * float(data_ef["% true actives identified"]), 1)
    print(f"Experimental EF for {percentage_ranked_dataset}% of ranked dataset:\t{data_ef}%")

# %%
def print_random_ef(percentage_ranked_dataset):
    '''
    Get random EF for x% of ranked dataset
        
    Parameters
    ----------
    percentage_ranked_dataset : float / int
        default the x% (percentage_ranked_dataset%) of ranked dataset.
        
    Returns
    -------
    None
    '''
    random_ef = round(float(percentage_ranked_dataset), 1)
    print(f"Random EF for {percentage_ranked_dataset}% of ranked dataset:\t\t{random_ef}%")

# %%
def print_optimal_ef(percentage_ranked_dataset, molecules_df, threshold):
    '''
    Get optimal random EF for x% of ranked dataset
        
    Parameters
    ----------
    percentage_ranked_dataset : float / int
        default the x% (percentage_ranked_dataset%) of ranked dataset.
    molecules_df : DataFrame
        the DataFrame with all the molecules and pIC50.
    threshold: float
        pIC50 cut-off value used to discriminate active and inactive compounds
        
    Returns
    -------
    None
    '''
    ratio = sum(molecules_df["pIC50"] >= threshold) / len(molecules_df) * 100
    if percentage_ranked_dataset <= ratio:
        optimal_ef = round(100 / ratio * percentage_ranked_dataset, 1)
    else:
        optimal_ef = round(float(100), 2)
    print(f"Optimal EF for {percentage_ranked_dataset}% of ranked dataset:\t\t{optimal_ef}%")

# %% [markdown]
# Now, we can calculate the enrichment factor(EF) for x% of ranked dataset and analyze the optimal EF with the threshold of pIC50 for active and inactive compounds.

# %%
# Choose percentage
percentage_x = 5

# TODO: CI : the output of print_data_ef(percentage_x, enrichment_data[i])
# Get EF data
for i, similarity in enumerate(similarity_measures):
    print(f"Similarity measure: {similarity}")
    print_data_ef(percentage_x, enrichment_data[i])
    print("\n")
print_random_ef(percentage_x)
print_optimal_ef(percentage_x, molecules_df, threshold)
# Out:
# Similarity measure: tanimoto_maccs
# Experimental EF for 5% of ranked dataset:	7.6%
#
#
# Similarity measure: tanimoto_morgan
# Experimental EF for 5% of ranked dataset:	8.3%
#
#
# Random EF for 5% of ranked dataset:		5.0%
# Optimal EF for 5% of ranked dataset:		9.2%

# %% [markdown]
# ## Discussion
#
# We have performed our virtual screening using the Tanimoto similarity. Of course, this could also be done using Dice or any other similarity measure.
#
# A drawback of a similarity search with molecular fingerprints is that it is based on molecular similarity and thus does not yield any novel structures. Another challenge when working with molecular similarity are so-called activity cliffs. A small change in a functional group of a molecule may initiate a jump in bioactivity.

# %% [markdown]
# ## Quiz
#
# * What could be a starting point to circumvent activity cliffs?
# * What are the advantages and disadvantages of MACCS and Morgan fingerprints compared to each other fingerprints?
# * How can you explain the different orders in the similarity dataframe depending on the fingerprint used?
